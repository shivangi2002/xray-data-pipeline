# %%
from image_dataset_definition import XRayDatasetDefinition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from image_dataset_definition import XRayDatasetDefinition
#
# File c:\Users\hp\Desktop\Shivangi\ai_ml_journey\xray-data-pipeline\image_dataset_definition.py:2
#       1 import os
# ----> 2 from PIL import Image
#       3 class XRayDatasetDefinition:
#       4     def __init__(self, dataset_path):
#
# ModuleNotFoundError: No module named 'PIL'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
DATASET_PATH = r"C:\Users\hp\Downloads\archive\chest_xray\train"

# %%
my_dataset = XRayDatasetDefinition(DATASET_PATH)

# %%
print("Dataset size:", len(my_dataset))
# Out:
# Dataset size: 5216

# %%
# Verify dataset structure
print("Classes:", list(my_dataset.class_to_label.keys()))

print("\nFirst sample:")
sample_path, sample_label = my_dataset.samples[0]
print("Path:", sample_path)
print("Label:", sample_label)
# Out:
# Classes: ['NORMAL', 'PNEUMONIA']
#
# First sample:
# Path: C:\Users\hp\Downloads\archive\chest_xray\train\NORMAL\IM-0115-0001.jpeg
# Label: 0

# %%
print(my_dataset[0])
# Out:
# ('C:\\Users\\hp\\Downloads\\archive\\chest_xray\\train\\NORMAL\\IM-0115-0001.jpeg', 0)
